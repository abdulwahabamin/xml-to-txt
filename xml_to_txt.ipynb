# %%
import xml.etree.ElementTree as ET
import os

# %%
#See sample xml file for reference
def parse_annotation(ann_dir, img_dir, labels=[], x_ratio =1, y_ratio = 1):
    all_imgs = []
    seen_labels = {}
    
    for ann in sorted(os.listdir(ann_dir)):
        img = {'object':[]}

        tree = ET.parse(ann_dir + ann)
        
        for elem in tree.iter():
            if 'filename' in elem.tag:
                img['filename'] = img_dir + elem.text
            if 'width' in elem.tag:
                img['width'] = int(elem.text)
            if 'height' in elem.tag:
                img['height'] = int(elem.text)
            if 'object' in elem.tag or 'part' in elem.tag:
                obj = {}
                
                for attr in list(elem):
                    if 'name' in attr.tag:
                        obj['name'] = attr.text

                        if obj['name'] in seen_labels:
                            seen_labels[obj['name']] += 1
                        else:
                            seen_labels[obj['name']] = 1
                        
                        if len(labels) > 0 and obj['name'] not in labels:
                            break
                        else:
                            img['object'] += [obj]
                            
                    if 'bndbox' in attr.tag:
                        for dim in list(attr):
                            if 'xmin' in dim.tag:
                                obj['xmin'] = int(round(float(dim.text))*x_ratio)
                            if 'ymin' in dim.tag:
                                obj['ymin'] = int(round(float(dim.text))*y_ratio)
                            if 'xmax' in dim.tag:
                                obj['xmax'] = int(round(float(dim.text))*x_ratio)
                            if 'ymax' in dim.tag:
                                obj['ymax'] = int(round(float(dim.text))*y_ratio)

        if len(img['object']) > 0:
            all_imgs += [img]
                        
    return all_imgs, seen_labels

# %%
LABELS = ['label'] # array containing labels. Can be more than one.
train_image_folder = 'Path to Images'
train_annot_folder = 'Path to Annotations folder'

train_imgs, seen_train_labels = parse_annotation(train_annot_folder, train_image_folder, labels=LABELS,)

label_ids = seen_train_labels.copy()

# %%
train_imgs #Checking data format
# Out:
# [{'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 1699,
#     'xmin': 1617,
#     'ymax': 813,
#     'ymin': 723}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1000.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1181,
#     'xmin': 1153,
#     'ymax': 667,
#     'ymin': 646},
#    {'name': 'garbage', 'xmax': 574, 'xmin': 551, 'ymax': 357, 'ymin': 326}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1001.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 565,
#     'xmin': 545,
#     'ymax': 450,
#     'ymin': 422}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1002.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 557,
#     'xmin': 532,
#     'ymax': 548,
#     'ymin': 520}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1003.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 548,
#     'xmin': 515,
#     'ymax': 659,
#     'ymin': 631}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1004.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 879,
#     'xmin': 858,
#     'ymax': 21,
#     'ymin': 1}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1005.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 876,
#     'xmin': 855,
#     'ymax': 79,
#     'ymin': 55}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1006.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 877,
#     'xmin': 850,
#     'ymax': 141,
#     'ymin': 119}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1007.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 872,
#     'xmin': 848,
#     'ymax': 209,
#     'ymin': 186},
#    {'name': 'garbage', 'xmax': 190, 'xmin': 158, 'ymax': 66, 'ymin': 45}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1008.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 873,
#     'xmin': 850,
#     'ymax': 287,
#     'ymin': 261},
#    {'name': 'garbage', 'xmax': 172, 'xmin': 140, 'ymax': 127, 'ymin': 104}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1009.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 154,
#     'xmin': 121,
#     'ymax': 189,
#     'ymin': 170},
#    {'name': 'garbage', 'xmax': 873, 'xmin': 846, 'ymax': 375, 'ymin': 344}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1010.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 873,
#     'xmin': 848,
#     'ymax': 464,
#     'ymin': 431},
#    {'name': 'garbage', 'xmax': 136, 'xmin': 103, 'ymax': 264, 'ymin': 239}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1011.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 114,
#     'xmin': 82,
#     'ymax': 344,
#     'ymin': 312},
#    {'name': 'garbage', 'xmax': 868, 'xmin': 844, 'ymax': 564, 'ymin': 524}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1012.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 91,
#     'xmin': 59,
#     'ymax': 431,
#     'ymin': 396},
#    {'name': 'garbage', 'xmax': 869, 'xmin': 838, 'ymax': 674, 'ymin': 635},
#    {'name': 'garbage', 'xmax': 197, 'xmin': 170, 'ymax': 45, 'ymin': 26}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1013.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 172,
#     'xmin': 152,
#     'ymax': 114,
#     'ymin': 88},
#    {'name': 'garbage', 'xmax': 66, 'xmin': 33, 'ymax': 525, 'ymin': 489}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1014.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 44,
#     'xmin': 9,
#     'ymax': 625,
#     'ymin': 589},
#    {'name': 'garbage', 'xmax': 152, 'xmin': 128, 'ymax': 187, 'ymin': 163}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1015.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 133,
#     'xmin': 103,
#     'ymax': 266,
#     'ymin': 241}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1016.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 106,
#     'xmin': 79,
#     'ymax': 354,
#     'ymin': 327}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1017.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 80,
#     'xmin': 49,
#     'ymax': 451,
#     'ymin': 421}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1018.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 55,
#     'xmin': 18,
#     'ymax': 555,
#     'ymin': 522}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1021.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 363,
#     'xmin': 342,
#     'ymax': 20,
#     'ymin': 1}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1022.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 344,
#     'xmin': 325,
#     'ymax': 90,
#     'ymin': 72}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1023.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 326,
#     'xmin': 307,
#     'ymax': 159,
#     'ymin': 141}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1024.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 310,
#     'xmin': 288,
#     'ymax': 241,
#     'ymin': 221}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1025.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 289,
#     'xmin': 269,
#     'ymax': 330,
#     'ymin': 306}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1026.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 268,
#     'xmin': 248,
#     'ymax': 431,
#     'ymin': 405},
#    {'name': 'garbage', 'xmax': 1160, 'xmin': 1140, 'ymax': 279, 'ymin': 238}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1027.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 244,
#     'xmin': 223,
#     'ymax': 536,
#     'ymin': 514},
#    {'name': 'garbage', 'xmax': 1168, 'xmin': 1144, 'ymax': 361, 'ymin': 322}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1028.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 218,
#     'xmin': 196,
#     'ymax': 659,
#     'ymin': 636},
#    {'name': 'garbage', 'xmax': 1171, 'xmin': 1154, 'ymax': 449, 'ymin': 403}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1029.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1182,
#     'xmin': 1162,
#     'ymax': 547,
#     'ymin': 494}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1030.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1190,
#     'xmin': 1167,
#     'ymax': 651,
#     'ymin': 596}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1039.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 426,
#     'xmin': 407,
#     'ymax': 46,
#     'ymin': 27}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1040.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 405,
#     'xmin': 388,
#     'ymax': 116,
#     'ymin': 97}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1041.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 377,
#     'xmin': 361,
#     'ymax': 191,
#     'ymin': 173}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1042.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 353,
#     'xmin': 334,
#     'ymax': 277,
#     'ymin': 258}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1043.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 326,
#     'xmin': 304,
#     'ymax': 371,
#     'ymin': 348}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1044.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 292,
#     'xmin': 272,
#     'ymax': 477,
#     'ymin': 456}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1045.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 261,
#     'xmin': 242,
#     'ymax': 594,
#     'ymin': 571}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1089.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 202,
#     'xmin': 178,
#     'ymax': 64,
#     'ymin': 36},
#    {'name': 'garbage', 'xmax': 986, 'xmin': 943, 'ymax': 91, 'ymin': 64}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1090.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 178,
#     'xmin': 154,
#     'ymax': 128,
#     'ymin': 102},
#    {'name': 'garbage', 'xmax': 986, 'xmin': 939, 'ymax': 156, 'ymin': 133}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1091.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 983,
#     'xmin': 938,
#     'ymax': 226,
#     'ymin': 201},
#    {'name': 'garbage', 'xmax': 151, 'xmin': 127, 'ymax': 205, 'ymin': 176}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1092.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 128,
#     'xmin': 100,
#     'ymax': 284,
#     'ymin': 262},
#    {'name': 'garbage', 'xmax': 984, 'xmin': 935, 'ymax': 302, 'ymin': 280}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1093.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 982,
#     'xmin': 927,
#     'ymax': 390,
#     'ymin': 365},
#    {'name': 'garbage', 'xmax': 104, 'xmin': 70, 'ymax': 374, 'ymin': 345},
#    {'name': 'garbage', 'xmax': 905, 'xmin': 868, 'ymax': 57, 'ymin': 34}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1094.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 72,
#     'xmin': 36,
#     'ymax': 471,
#     'ymin': 446},
#    {'name': 'garbage', 'xmax': 972, 'xmin': 925, 'ymax': 487, 'ymin': 457},
#    {'name': 'garbage', 'xmax': 908, 'xmin': 876, 'ymax': 122, 'ymin': 97},
#    {'name': 'garbage', 'xmax': 1178, 'xmin': 1159, 'ymax': 31, 'ymin': 9}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1095.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 975,
#     'xmin': 925,
#     'ymax': 591,
#     'ymin': 560},
#    {'name': 'garbage', 'xmax': 46, 'xmin': 3, 'ymax': 578, 'ymin': 555},
#    {'name': 'garbage', 'xmax': 1193, 'xmin': 1171, 'ymax': 90, 'ymin': 65},
#    {'name': 'garbage', 'xmax': 914, 'xmin': 877, 'ymax': 189, 'ymin': 168}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1096.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 973,
#     'xmin': 926,
#     'ymax': 711,
#     'ymin': 663},
#    {'name': 'garbage', 'xmax': 922, 'xmin': 884, 'ymax': 266, 'ymin': 241},
#    {'name': 'garbage', 'xmax': 1202, 'xmin': 1182, 'ymax': 157, 'ymin': 121},
#    {'name': 'garbage', 'xmax': 1128, 'xmin': 1105, 'ymax': 48, 'ymin': 28}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1097.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1136,
#     'xmin': 1115,
#     'ymax': 110,
#     'ymin': 89},
#    {'name': 'garbage', 'xmax': 1214, 'xmin': 1192, 'ymax': 222, 'ymin': 191},
#    {'name': 'garbage', 'xmax': 922, 'xmin': 889, 'ymax': 350, 'ymin': 322}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1098.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 928,
#     'xmin': 893,
#     'ymax': 441,
#     'ymin': 407},
#    {'name': 'garbage', 'xmax': 1231, 'xmin': 1202, 'ymax': 297, 'ymin': 265},
#    {'name': 'garbage', 'xmax': 1147, 'xmin': 1121, 'ymax': 179, 'ymin': 153}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1099.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1153,
#     'xmin': 1128,
#     'ymax': 250,
#     'ymin': 221},
#    {'name': 'garbage', 'xmax': 1250, 'xmin': 1217, 'ymax': 377, 'ymin': 347},
#    {'name': 'garbage', 'xmax': 934, 'xmin': 891, 'ymax': 542, 'ymin': 508}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1100.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 926,
#     'xmin': 881,
#     'ymax': 650,
#     'ymin': 615},
#    {'name': 'garbage', 'xmax': 1165, 'xmin': 1137, 'ymax': 330, 'ymin': 301},
#    {'name': 'garbage', 'xmax': 1263, 'xmin': 1234, 'ymax': 462, 'ymin': 428}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1101.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1278,
#     'xmin': 1248,
#     'ymax': 552,
#     'ymin': 527},
#    {'name': 'garbage', 'xmax': 1170, 'xmin': 1139, 'ymax': 413, 'ymin': 387}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1102.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1174,
#     'xmin': 1142,
#     'ymax': 505,
#     'ymin': 475},
#    {'name': 'garbage', 'xmax': 1280, 'xmin': 1260, 'ymax': 650, 'ymin': 620},
#    {'name': 'garbage', 'xmax': 766, 'xmin': 723, 'ymax': 106, 'ymin': 78}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1103.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 764,
#     'xmin': 748,
#     'ymax': 171,
#     'ymin': 152},
#    {'name': 'garbage', 'xmax': 1178, 'xmin': 1147, 'ymax': 604, 'ymin': 572}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1104.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1181,
#     'xmin': 1149,
#     'ymax': 713,
#     'ymin': 676},
#    {'name': 'garbage', 'xmax': 772, 'xmin': 746, 'ymax': 243, 'ymin': 225}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1105.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 772,
#     'xmin': 752,
#     'ymax': 318,
#     'ymin': 302}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1106.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 773,
#     'xmin': 757,
#     'ymax': 401,
#     'ymin': 381},
#    {'name': 'garbage', 'xmax': 203, 'xmin': 179, 'ymax': 49, 'ymin': 33}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1107.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 190,
#     'xmin': 167,
#     'ymax': 109,
#     'ymin': 86},
#    {'name': 'garbage', 'xmax': 778, 'xmin': 753, 'ymax': 490, 'ymin': 472}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1108.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 775,
#     'xmin': 755,
#     'ymax': 590,
#     'ymin': 568},
#    {'name': 'garbage', 'xmax': 180, 'xmin': 152, 'ymax': 175, 'ymin': 150},
#    {'name': 'garbage', 'xmax': 602, 'xmin': 588, 'ymax': 54, 'ymin': 44}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1109.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 777,
#     'xmin': 754,
#     'ymax': 697,
#     'ymin': 677},
#    {'name': 'garbage', 'xmax': 165, 'xmin': 142, 'ymax': 241, 'ymin': 219},
#    {'name': 'garbage', 'xmax': 590, 'xmin': 578, 'ymax': 124, 'ymin': 111}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1110.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 153,
#     'xmin': 128,
#     'ymax': 320,
#     'ymin': 295},
#    {'name': 'garbage', 'xmax': 588, 'xmin': 565, 'ymax': 203, 'ymin': 183}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1111.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 579,
#     'xmin': 553,
#     'ymax': 289,
#     'ymin': 264},
#    {'name': 'garbage', 'xmax': 141, 'xmin': 109, 'ymax': 402, 'ymin': 375},
#    {'name': 'garbage', 'xmax': 848, 'xmin': 830, 'ymax': 55, 'ymin': 37}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1112.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 127,
#     'xmin': 98,
#     'ymax': 491,
#     'ymin': 469},
#    {'name': 'garbage', 'xmax': 566, 'xmin': 539, 'ymax': 374, 'ymin': 357},
#    {'name': 'garbage', 'xmax': 847, 'xmin': 830, 'ymax': 115, 'ymin': 100},
#    {'name': 'garbage', 'xmax': 1208, 'xmin': 1184, 'ymax': 65, 'ymin': 42}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1113.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1229,
#     'xmin': 1204,
#     'ymax': 131,
#     'ymin': 109},
#    {'name': 'garbage', 'xmax': 848, 'xmin': 827, 'ymax': 189, 'ymin': 164},
#    {'name': 'garbage', 'xmax': 553, 'xmin': 528, 'ymax': 471, 'ymin': 448},
#    {'name': 'garbage', 'xmax': 115, 'xmin': 81, 'ymax': 592, 'ymin': 566}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1114.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 100,
#     'xmin': 63,
#     'ymax': 707,
#     'ymin': 672},
#    {'name': 'garbage', 'xmax': 538, 'xmin': 518, 'ymax': 582, 'ymin': 560},
#    {'name': 'garbage', 'xmax': 850, 'xmin': 828, 'ymax': 259, 'ymin': 242},
#    {'name': 'garbage', 'xmax': 1252, 'xmin': 1220, 'ymax': 201, 'ymin': 178}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1115.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 524,
#     'xmin': 504,
#     'ymax': 705,
#     'ymin': 682},
#    {'name': 'garbage', 'xmax': 846, 'xmin': 826, 'ymax': 343, 'ymin': 325},
#    {'name': 'garbage', 'xmax': 1275, 'xmin': 1243, 'ymax': 283, 'ymin': 256}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1116.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 844,
#     'xmin': 825,
#     'ymax': 434,
#     'ymin': 413}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1117.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 841,
#     'xmin': 824,
#     'ymax': 532,
#     'ymin': 511}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1118.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 839,
#     'xmin': 816,
#     'ymax': 643,
#     'ymin': 621}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1129.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 632,
#     'xmin': 605,
#     'ymax': 57,
#     'ymin': 32}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1130.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 632,
#     'xmin': 600,
#     'ymax': 128,
#     'ymin': 105}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1131.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 624,
#     'xmin': 593,
#     'ymax': 204,
#     'ymin': 175}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1132.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 615,
#     'xmin': 586,
#     'ymax': 286,
#     'ymin': 259}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1133.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 603,
#     'xmin': 571,
#     'ymax': 376,
#     'ymin': 345}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1134.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 592,
#     'xmin': 556,
#     'ymax': 475,
#     'ymin': 444}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1136.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 558,
#     'xmin': 523,
#     'ymax': 716,
#     'ymin': 673}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1141.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 553,
#     'xmin': 540,
#     'ymax': 64,
#     'ymin': 52},
#    {'name': 'garbage', 'xmax': 1239, 'xmin': 1211, 'ymax': 27, 'ymin': 8}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1142.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1252,
#     'xmin': 1222,
#     'ymax': 82,
#     'ymin': 61},
#    {'name': 'garbage', 'xmax': 546, 'xmin': 534, 'ymax': 135, 'ymin': 125}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1143.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 538,
#     'xmin': 524,
#     'ymax': 216,
#     'ymin': 202},
#    {'name': 'garbage', 'xmax': 1264, 'xmin': 1236, 'ymax': 145, 'ymin': 117}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1144.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1277,
#     'xmin': 1244,
#     'ymax': 211,
#     'ymin': 184},
#    {'name': 'garbage', 'xmax': 524, 'xmin': 508, 'ymax': 302, 'ymin': 289}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1145.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 511,
#     'xmin': 493,
#     'ymax': 402,
#     'ymin': 387},
#    {'name': 'garbage', 'xmax': 1280, 'xmin': 1259, 'ymax': 284, 'ymin': 255}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1146.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 492,
#     'xmin': 474,
#     'ymax': 511,
#     'ymin': 498}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1147.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 470,
#     'xmin': 453,
#     'ymax': 631,
#     'ymin': 617}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1152.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 844,
#     'xmin': 804,
#     'ymax': 51,
#     'ymin': 27},
#    {'name': 'garbage', 'xmax': 1182, 'xmin': 1156, 'ymax': 171, 'ymin': 152}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1153.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 838,
#     'xmin': 795,
#     'ymax': 116,
#     'ymin': 87},
#    {'name': 'garbage', 'xmax': 1189, 'xmin': 1162, 'ymax': 238, 'ymin': 225}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1154.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 835,
#     'xmin': 793,
#     'ymax': 192,
#     'ymin': 156},
#    {'name': 'garbage', 'xmax': 1196, 'xmin': 1168, 'ymax': 318, 'ymin': 304}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1155.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1200,
#     'xmin': 1172,
#     'ymax': 392,
#     'ymin': 381},
#    {'name': 'garbage', 'xmax': 824, 'xmin': 784, 'ymax': 268, 'ymin': 226}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1156.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 821,
#     'xmin': 778,
#     'ymax': 356,
#     'ymin': 309},
#    {'name': 'garbage', 'xmax': 1199, 'xmin': 1171, 'ymax': 476, 'ymin': 461}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1157.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1198,
#     'xmin': 1173,
#     'ymax': 567,
#     'ymin': 550},
#    {'name': 'garbage', 'xmax': 801, 'xmin': 770, 'ymax': 450, 'ymin': 413}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1158.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 794,
#     'xmin': 759,
#     'ymax': 556,
#     'ymin': 511},
#    {'name': 'garbage', 'xmax': 1192, 'xmin': 1162, 'ymax': 669, 'ymin': 646}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1159.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 780,
#     'xmin': 744,
#     'ymax': 676,
#     'ymin': 635},
#    {'name': 'garbage', 'xmax': 1230, 'xmin': 1215, 'ymax': 36, 'ymin': 13}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1160.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1237,
#     'xmin': 1223,
#     'ymax': 96,
#     'ymin': 76},
#    {'name': 'garbage', 'xmax': 1246, 'xmin': 1228, 'ymax': 141, 'ymin': 121}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1161.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1248,
#     'xmin': 1224,
#     'ymax': 160,
#     'ymin': 145},
#    {'name': 'garbage', 'xmax': 1264, 'xmin': 1248, 'ymax': 216, 'ymin': 193}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1162.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1260,
#     'xmin': 1232,
#     'ymax': 232,
#     'ymin': 215}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1163.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1272,
#     'xmin': 1248,
#     'ymax': 304,
#     'ymin': 291}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1164.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 371,
#     'xmin': 352,
#     'ymax': 51,
#     'ymin': 27},
#    {'name': 'garbage', 'xmax': 1280, 'xmin': 1259, 'ymax': 388, 'ymin': 367}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1165.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 358,
#     'xmin': 333,
#     'ymax': 121,
#     'ymin': 99}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1166.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 336,
#     'xmin': 309,
#     'ymax': 198,
#     'ymin': 179},
#    {'name': 'garbage', 'xmax': 604, 'xmin': 577, 'ymax': 45, 'ymin': 22}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1167.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 314,
#     'xmin': 288,
#     'ymax': 282,
#     'ymin': 261},
#    {'name': 'garbage', 'xmax': 596, 'xmin': 572, 'ymax': 114, 'ymin': 92}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1168.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 293,
#     'xmin': 263,
#     'ymax': 375,
#     'ymin': 348},
#    {'name': 'garbage', 'xmax': 585, 'xmin': 562, 'ymax': 190, 'ymin': 167}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1169.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 263,
#     'xmin': 235,
#     'ymax': 478,
#     'ymin': 455},
#    {'name': 'garbage', 'xmax': 572, 'xmin': 545, 'ymax': 277, 'ymin': 249},
#    {'name': 'garbage', 'xmax': 143, 'xmin': 103, 'ymax': 46, 'ymin': 9}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1170.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 566,
#     'xmin': 538,
#     'ymax': 368,
#     'ymin': 342},
#    {'name': 'garbage', 'xmax': 237, 'xmin': 209, 'ymax': 598, 'ymin': 569},
#    {'name': 'garbage', 'xmax': 115, 'xmin': 75, 'ymax': 119, 'ymin': 74}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1171.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 200,
#     'xmin': 176,
#     'ymax': 720,
#     'ymin': 692},
#    {'name': 'garbage', 'xmax': 548, 'xmin': 524, 'ymax': 473, 'ymin': 442},
#    {'name': 'garbage', 'xmax': 88, 'xmin': 48, 'ymax': 200, 'ymin': 150}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1172.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 61,
#     'xmin': 16,
#     'ymax': 285,
#     'ymin': 236},
#    {'name': 'garbage', 'xmax': 533, 'xmin': 510, 'ymax': 591, 'ymin': 556}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1173.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 518,
#     'xmin': 488,
#     'ymax': 717,
#     'ymin': 680},
#    {'name': 'garbage', 'xmax': 29, 'xmin': 1, 'ymax': 379, 'ymin': 322}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1188.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 394,
#     'xmin': 375,
#     'ymax': 31,
#     'ymin': 13}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1189.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 376,
#     'xmin': 361,
#     'ymax': 96,
#     'ymin': 76}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im119.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 564,
#     'xmin': 525,
#     'ymax': 35,
#     'ymin': 4}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1190.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 363,
#     'xmin': 344,
#     'ymax': 168,
#     'ymin': 148}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1191.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 352,
#     'xmin': 328,
#     'ymax': 252,
#     'ymin': 228},
#    {'name': 'garbage', 'xmax': 1168, 'xmin': 1141, 'ymax': 49, 'ymin': 27}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1192.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1174,
#     'xmin': 1150,
#     'ymax': 114,
#     'ymin': 90},
#    {'name': 'garbage', 'xmax': 336, 'xmin': 315, 'ymax': 341, 'ymin': 315}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1193.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 322,
#     'xmin': 302,
#     'ymax': 434,
#     'ymin': 411},
#    {'name': 'garbage', 'xmax': 1182, 'xmin': 1158, 'ymax': 181, 'ymin': 156}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1194.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1193,
#     'xmin': 1168,
#     'ymax': 259,
#     'ymin': 235},
#    {'name': 'garbage', 'xmax': 310, 'xmin': 291, 'ymax': 543, 'ymin': 518}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1195.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 302,
#     'xmin': 280,
#     'ymax': 664,
#     'ymin': 633},
#    {'name': 'garbage', 'xmax': 1204, 'xmin': 1176, 'ymax': 339, 'ymin': 313}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1196.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1212,
#     'xmin': 1181,
#     'ymax': 426,
#     'ymin': 405}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1197.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1221,
#     'xmin': 1188,
#     'ymax': 526,
#     'ymin': 495}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1198.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1228,
#     'xmin': 1193,
#     'ymax': 631,
#     'ymin': 601}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im120.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 567,
#     'xmin': 505,
#     'ymax': 134,
#     'ymin': 86}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1202.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 948,
#     'xmin': 933,
#     'ymax': 136,
#     'ymin': 124},
#    {'name': 'garbage', 'xmax': 1000, 'xmin': 957, 'ymax': 65, 'ymin': 46}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1203.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1005,
#     'xmin': 964,
#     'ymax': 128,
#     'ymin': 105},
#    {'name': 'garbage', 'xmax': 948, 'xmin': 925, 'ymax': 212, 'ymin': 188}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1204.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1008,
#     'xmin': 971,
#     'ymax': 194,
#     'ymin': 172},
#    {'name': 'garbage', 'xmax': 944, 'xmin': 924, 'ymax': 289, 'ymin': 272}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1205.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 941,
#     'xmin': 921,
#     'ymax': 374,
#     'ymin': 356},
#    {'name': 'garbage', 'xmax': 1014, 'xmin': 974, 'ymax': 267, 'ymin': 245}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1206.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 938,
#     'xmin': 918,
#     'ymax': 463,
#     'ymin': 450},
#    {'name': 'garbage', 'xmax': 1020, 'xmin': 978, 'ymax': 339, 'ymin': 321}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1207.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 931,
#     'xmin': 918,
#     'ymax': 568,
#     'ymin': 547},
#    {'name': 'garbage', 'xmax': 1027, 'xmin': 987, 'ymax': 420, 'ymin': 396}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1208.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 927,
#     'xmin': 908,
#     'ymax': 677,
#     'ymin': 657},
#    {'name': 'garbage', 'xmax': 1026, 'xmin': 982, 'ymax': 510, 'ymin': 486}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1209.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1030,
#     'xmin': 982,
#     'ymax': 608,
#     'ymin': 581}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im121.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 552,
#     'xmin': 503,
#     'ymax': 234,
#     'ymin': 179}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1210.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1028,
#     'xmin': 982,
#     'ymax': 713,
#     'ymin': 681}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1216.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 508,
#     'xmin': 477,
#     'ymax': 43,
#     'ymin': 21}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1217.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 504,
#     'xmin': 464,
#     'ymax': 113,
#     'ymin': 87}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1218.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 491,
#     'xmin': 455,
#     'ymax': 186,
#     'ymin': 161}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1219.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 484,
#     'xmin': 447,
#     'ymax': 268,
#     'ymin': 241}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im122.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 553,
#     'xmin': 490,
#     'ymax': 345,
#     'ymin': 292}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1220.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 479,
#     'xmin': 436,
#     'ymax': 358,
#     'ymin': 332},
#    {'name': 'garbage', 'xmax': 427, 'xmin': 403, 'ymax': 277, 'ymin': 249}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1221.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 461,
#     'xmin': 426,
#     'ymax': 461,
#     'ymin': 429},
#    {'name': 'garbage', 'xmax': 424, 'xmin': 392, 'ymax': 373, 'ymin': 337}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1222.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 454,
#     'xmin': 411,
#     'ymax': 572,
#     'ymin': 537},
#    {'name': 'garbage', 'xmax': 413, 'xmin': 385, 'ymax': 470, 'ymin': 440}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1223.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 440,
#     'xmin': 391,
#     'ymax': 699,
#     'ymin': 664},
#    {'name': 'garbage', 'xmax': 407, 'xmin': 375, 'ymax': 580, 'ymin': 544}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1224.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 398,
#     'xmin': 367,
#     'ymax': 703,
#     'ymin': 671}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im123.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 547,
#     'xmin': 482,
#     'ymax': 461,
#     'ymin': 401}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im124.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 534,
#     'xmin': 466,
#     'ymax': 585,
#     'ymin': 532}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1244.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1159,
#     'xmin': 1131,
#     'ymax': 41,
#     'ymin': 21}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1245.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1170,
#     'xmin': 1143,
#     'ymax': 102,
#     'ymin': 79},
#    {'name': 'garbage', 'xmax': 42, 'xmin': 10, 'ymax': 62, 'ymin': 40}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1246.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1180,
#     'xmin': 1148,
#     'ymax': 168,
#     'ymin': 146}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1247.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1188,
#     'xmin': 1160,
#     'ymax': 236,
#     'ymin': 213}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1248.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1195,
#     'xmin': 1169,
#     'ymax': 315,
#     'ymin': 292}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1249.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1200,
#     'xmin': 1168,
#     'ymax': 397,
#     'ymin': 376}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im125.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 537,
#     'xmin': 456,
#     'ymax': 731,
#     'ymin': 663}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1250.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1210,
#     'xmin': 1178,
#     'ymax': 491,
#     'ymin': 462},
#    {'name': 'garbage', 'xmax': 656, 'xmin': 623, 'ymax': 20, 'ymin': 6}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1251.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1215,
#     'xmin': 1178,
#     'ymax': 588,
#     'ymin': 568},
#    {'name': 'garbage', 'xmax': 646, 'xmin': 619, 'ymax': 91, 'ymin': 68}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1252.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1212,
#     'xmin': 1181,
#     'ymax': 695,
#     'ymin': 672},
#    {'name': 'garbage', 'xmax': 645, 'xmin': 612, 'ymax': 159, 'ymin': 140}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1253.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 643,
#     'xmin': 610,
#     'ymax': 231,
#     'ymin': 209}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1254.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 641,
#     'xmin': 608,
#     'ymax': 321,
#     'ymin': 294}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1255.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 638,
#     'xmin': 605,
#     'ymax': 410,
#     'ymin': 381}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1256.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 635,
#     'xmin': 602,
#     'ymax': 510,
#     'ymin': 481}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1257.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 635,
#     'xmin': 604,
#     'ymax': 619,
#     'ymin': 586}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im126.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 528,
#     'xmin': 467,
#     'ymax': 876,
#     'ymin': 809}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1263.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 634,
#     'xmin': 596,
#     'ymax': 53,
#     'ymin': 16}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1264.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 380,
#     'xmin': 357,
#     'ymax': 57,
#     'ymin': 36},
#    {'name': 'garbage', 'xmax': 622, 'xmin': 582, 'ymax': 119, 'ymin': 78}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1265.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 377,
#     'xmin': 355,
#     'ymax': 122,
#     'ymin': 105},
#    {'name': 'garbage', 'xmax': 617, 'xmin': 572, 'ymax': 193, 'ymin': 148}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1266.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 606,
#     'xmin': 558,
#     'ymax': 278,
#     'ymin': 225},
#    {'name': 'garbage', 'xmax': 373, 'xmin': 345, 'ymax': 196, 'ymin': 172}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1267.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 367,
#     'xmin': 342,
#     'ymax': 281,
#     'ymin': 249},
#    {'name': 'garbage', 'xmax': 594, 'xmin': 547, 'ymax': 363, 'ymin': 307}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1268.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 582,
#     'xmin': 527,
#     'ymax': 461,
#     'ymin': 402},
#    {'name': 'garbage', 'xmax': 362, 'xmin': 330, 'ymax': 361, 'ymin': 331}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1269.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 576,
#     'xmin': 513,
#     'ymax': 572,
#     'ymin': 507},
#    {'name': 'garbage', 'xmax': 356, 'xmin': 324, 'ymax': 458, 'ymin': 430}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im127.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 532,
#     'xmin': 456,
#     'ymax': 1037,
#     'ymin': 962}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1270.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 351,
#     'xmin': 314,
#     'ymax': 569,
#     'ymin': 533}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1271.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 334,
#     'xmin': 298,
#     'ymax': 687,
#     'ymin': 658}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1276.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 819,
#     'xmin': 782,
#     'ymax': 59,
#     'ymin': 39}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1277.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 823,
#     'xmin': 778,
#     'ymax': 123,
#     'ymin': 101}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1278.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 822,
#     'xmin': 782,
#     'ymax': 196,
#     'ymin': 172}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1279.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 826,
#     'xmin': 782,
#     'ymax': 272,
#     'ymin': 245},
#    {'name': 'garbage', 'xmax': 414, 'xmin': 398, 'ymax': 241, 'ymin': 224}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1280.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 828,
#     'xmin': 784,
#     'ymax': 352,
#     'ymin': 325},
#    {'name': 'garbage', 'xmax': 400, 'xmin': 384, 'ymax': 327, 'ymin': 316}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1281.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 836,
#     'xmin': 783,
#     'ymax': 442,
#     'ymin': 415},
#    {'name': 'garbage', 'xmax': 381, 'xmin': 365, 'ymax': 429, 'ymin': 412}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1282.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 839,
#     'xmin': 788,
#     'ymax': 537,
#     'ymin': 506},
#    {'name': 'garbage', 'xmax': 363, 'xmin': 347, 'ymax': 542, 'ymin': 519},
#    {'name': 'garbage', 'xmax': 1178, 'xmin': 1159, 'ymax': 71, 'ymin': 50}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1283.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 845,
#     'xmin': 789,
#     'ymax': 648,
#     'ymin': 609},
#    {'name': 'garbage', 'xmax': 342, 'xmin': 322, 'ymax': 665, 'ymin': 641},
#    {'name': 'garbage', 'xmax': 1191, 'xmin': 1168, 'ymax': 133, 'ymin': 115}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1284.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1202,
#     'xmin': 1178,
#     'ymax': 207,
#     'ymin': 179}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1285.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1210,
#     'xmin': 1188,
#     'ymax': 288,
#     'ymin': 260}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1286.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1220,
#     'xmin': 1196,
#     'ymax': 369,
#     'ymin': 339}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1287.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1226,
#     'xmin': 1199,
#     'ymax': 457,
#     'ymin': 426}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1288.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1226,
#     'xmin': 1203,
#     'ymax': 554,
#     'ymin': 523},
#    {'name': 'garbage', 'xmax': 618, 'xmin': 575, 'ymax': 37, 'ymin': 7}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1289.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 603,
#     'xmin': 561,
#     'ymax': 97,
#     'ymin': 66},
#    {'name': 'garbage', 'xmax': 1232, 'xmin': 1201, 'ymax': 653, 'ymin': 626}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1290.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 592,
#     'xmin': 543,
#     'ymax': 166,
#     'ymin': 130}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1291.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 578,
#     'xmin': 529,
#     'ymax': 233,
#     'ymin': 194}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1292.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 562,
#     'xmin': 512,
#     'ymax': 311,
#     'ymin': 267},
#    {'name': 'garbage', 'xmax': 342, 'xmin': 316, 'ymax': 55, 'ymin': 36}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1293.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 332,
#     'xmin': 306,
#     'ymax': 117,
#     'ymin': 103},
#    {'name': 'garbage', 'xmax': 544, 'xmin': 497, 'ymax': 397, 'ymin': 342}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1294.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 533,
#     'xmin': 478,
#     'ymax': 485,
#     'ymin': 430},
#    {'name': 'garbage', 'xmax': 324, 'xmin': 290, 'ymax': 187, 'ymin': 172}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1295.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 511,
#     'xmin': 466,
#     'ymax': 585,
#     'ymin': 528},
#    {'name': 'garbage', 'xmax': 308, 'xmin': 272, 'ymax': 266, 'ymin': 244}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1296.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 286,
#     'xmin': 258,
#     'ymax': 348,
#     'ymin': 326}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1297.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 267,
#     'xmin': 239,
#     'ymax': 444,
#     'ymin': 421},
#    {'name': 'garbage', 'xmax': 1038, 'xmin': 1006, 'ymax': 19, 'ymin': 1}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im1298.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
# ...
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 449,
#     'xmin': 361,
#     'ymax': 338,
#     'ymin': 278}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im923.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 440,
#     'xmin': 412,
#     'ymax': 20,
#     'ymin': 1},
#    {'name': 'garbage', 'xmax': 330, 'xmin': 306, 'ymax': 645, 'ymin': 616}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im924.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 434,
#     'xmin': 403,
#     'ymax': 87,
#     'ymin': 72}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im925.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 422,
#     'xmin': 394,
#     'ymax': 163,
#     'ymin': 147}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im926.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 408,
#     'xmin': 377,
#     'ymax': 249,
#     'ymin': 230},
#    {'name': 'garbage', 'xmax': 1231, 'xmin': 1187, 'ymax': 36, 'ymin': 3}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im927.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 392,
#     'xmin': 364,
#     'ymax': 343,
#     'ymin': 326},
#    {'name': 'garbage', 'xmax': 1242, 'xmin': 1202, 'ymax': 95, 'ymin': 57}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im928.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1255,
#     'xmin': 1213,
#     'ymax': 151,
#     'ymin': 115},
#    {'name': 'garbage', 'xmax': 380, 'xmin': 347, 'ymax': 452, 'ymin': 434}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im929.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 361,
#     'xmin': 328,
#     'ymax': 572,
#     'ymin': 552},
#    {'name': 'garbage', 'xmax': 1266, 'xmin': 1222, 'ymax': 212, 'ymin': 174}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im93.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 424,
#     'xmin': 343,
#     'ymax': 475,
#     'ymin': 413}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im930.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 342,
#     'xmin': 305,
#     'ymax': 707,
#     'ymin': 685},
#    {'name': 'garbage', 'xmax': 1280, 'xmin': 1236, 'ymax': 277, 'ymin': 237}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im931.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1280,
#     'xmin': 1244,
#     'ymax': 347,
#     'ymin': 307}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im932.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1280,
#     'xmin': 1252,
#     'ymax': 424,
#     'ymin': 376},
#    {'name': 'garbage', 'xmax': 953, 'xmin': 931, 'ymax': 25, 'ymin': 8}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im933.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 957,
#     'xmin': 933,
#     'ymax': 90,
#     'ymin': 66},
#    {'name': 'garbage', 'xmax': 1280, 'xmin': 1259, 'ymax': 501, 'ymin': 454}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im934.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 958,
#     'xmin': 938,
#     'ymax': 156,
#     'ymin': 136}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im935.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 965,
#     'xmin': 938,
#     'ymax': 229,
#     'ymin': 206}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im936.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 968,
#     'xmin': 945,
#     'ymax': 308,
#     'ymin': 282}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im937.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 972,
#     'xmin': 945,
#     'ymax': 393,
#     'ymin': 369}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im938.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 973,
#     'xmin': 950,
#     'ymax': 486,
#     'ymin': 460}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im939.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 978,
#     'xmin': 953,
#     'ymax': 586,
#     'ymin': 563}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im94.jpg',
#   'height': 1080,
#   'object': [{'name': 'garbage',
#     'xmax': 406,
#     'xmin': 335,
#     'ymax': 628,
#     'ymin': 557}],
#   'width': 1920},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im940.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 982,
#     'xmin': 950,
#     'ymax': 703,
#     'ymin': 673}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im952.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1001,
#     'xmin': 928,
#     'ymax': 106,
#     'ymin': 55}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im953.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 398,
#     'xmin': 382,
#     'ymax': 42,
#     'ymin': 20},
#    {'name': 'garbage', 'xmax': 1004, 'xmin': 930, 'ymax': 173, 'ymin': 119}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im954.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1008,
#     'xmin': 932,
#     'ymax': 246,
#     'ymin': 187},
#    {'name': 'garbage', 'xmax': 391, 'xmin': 369, 'ymax': 106, 'ymin': 82}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im955.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 380,
#     'xmin': 358,
#     'ymax': 178,
#     'ymin': 154},
#    {'name': 'garbage', 'xmax': 1014, 'xmin': 935, 'ymax': 328, 'ymin': 263}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im956.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1014,
#     'xmin': 938,
#     'ymax': 408,
#     'ymin': 342},
#    {'name': 'garbage', 'xmax': 370, 'xmin': 347, 'ymax': 257, 'ymin': 230}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im957.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 363,
#     'xmin': 337,
#     'ymax': 347,
#     'ymin': 316},
#    {'name': 'garbage', 'xmax': 1025, 'xmin': 943, 'ymax': 505, 'ymin': 434}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im958.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1032,
#     'xmin': 943,
#     'ymax': 604,
#     'ymin': 532},
#    {'name': 'garbage', 'xmax': 352, 'xmin': 323, 'ymax': 446, 'ymin': 412}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im959.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 341,
#     'xmin': 312,
#     'ymax': 556,
#     'ymin': 520},
#    {'name': 'garbage', 'xmax': 1048, 'xmin': 943, 'ymax': 713, 'ymin': 636}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im960.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 331,
#     'xmin': 294,
#     'ymax': 678,
#     'ymin': 644}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im965.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1181,
#     'xmin': 1160,
#     'ymax': 57,
#     'ymin': 36}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im966.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1196,
#     'xmin': 1168,
#     'ymax': 119,
#     'ymin': 103}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im967.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1211,
#     'xmin': 1182,
#     'ymax': 190,
#     'ymin': 169}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im968.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1220,
#     'xmin': 1193,
#     'ymax': 262,
#     'ymin': 244}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im969.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1237,
#     'xmin': 1206,
#     'ymax': 340,
#     'ymin': 318}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im970.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1249,
#     'xmin': 1219,
#     'ymax': 424,
#     'ymin': 401},
#    {'name': 'garbage', 'xmax': 1228, 'xmin': 1193, 'ymax': 73, 'ymin': 34}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im971.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1261,
#     'xmin': 1228,
#     'ymax': 516,
#     'ymin': 491},
#    {'name': 'garbage', 'xmax': 1245, 'xmin': 1206, 'ymax': 132, 'ymin': 97}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im972.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1267,
#     'xmin': 1235,
#     'ymax': 613,
#     'ymin': 588},
#    {'name': 'garbage', 'xmax': 1257, 'xmin': 1220, 'ymax': 200, 'ymin': 152}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im973.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1276,
#     'xmin': 1244,
#     'ymax': 720,
#     'ymin': 692},
#    {'name': 'garbage', 'xmax': 1267, 'xmin': 1230, 'ymax': 267, 'ymin': 221}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im974.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1278,
#     'xmin': 1247,
#     'ymax': 351,
#     'ymin': 297}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im975.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1273,
#     'xmin': 1242,
#     'ymax': 284,
#     'ymin': 255},
#    {'name': 'garbage', 'xmax': 1153, 'xmin': 1128, 'ymax': 69, 'ymin': 47}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im976.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1164,
#     'xmin': 1140,
#     'ymax': 130,
#     'ymin': 112},
#    {'name': 'garbage', 'xmax': 1263, 'xmin': 1235, 'ymax': 351, 'ymin': 319}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im977.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1178,
#     'xmin': 1152,
#     'ymax': 203,
#     'ymin': 181}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im978.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1188,
#     'xmin': 1162,
#     'ymax': 277,
#     'ymin': 253}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im979.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1199,
#     'xmin': 1168,
#     'ymax': 360,
#     'ymin': 330}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im980.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1207,
#     'xmin': 1180,
#     'ymax': 441,
#     'ymin': 411}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im981.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1216,
#     'xmin': 1188,
#     'ymax': 534,
#     'ymin': 505}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im982.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1221,
#     'xmin': 1193,
#     'ymax': 634,
#     'ymin': 600}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im983.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 418,
#     'xmin': 386,
#     'ymax': 67,
#     'ymin': 47},
#    {'name': 'garbage', 'xmax': 425, 'xmin': 404, 'ymax': 272, 'ymin': 249}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im984.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 398,
#     'xmin': 378,
#     'ymax': 140,
#     'ymin': 113},
#    {'name': 'garbage', 'xmax': 411, 'xmin': 389, 'ymax': 360, 'ymin': 332}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im985.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 391,
#     'xmin': 359,
#     'ymax': 215,
#     'ymin': 191},
#    {'name': 'garbage', 'xmax': 393, 'xmin': 373, 'ymax': 460, 'ymin': 433}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im986.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 374,
#     'xmin': 343,
#     'ymax': 301,
#     'ymin': 267},
#    {'name': 'garbage', 'xmax': 378, 'xmin': 355, 'ymax': 576, 'ymin': 542}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im987.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 357,
#     'xmin': 324,
#     'ymax': 395,
#     'ymin': 362},
#    {'name': 'garbage', 'xmax': 358, 'xmin': 333, 'ymax': 695, 'ymin': 663}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im988.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 343,
#     'xmin': 306,
#     'ymax': 497,
#     'ymin': 465}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im989.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 318,
#     'xmin': 288,
#     'ymax': 613,
#     'ymin': 576}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im990.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 179,
#     'xmin': 156,
#     'ymax': 61,
#     'ymin': 48}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im991.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 158,
#     'xmin': 139,
#     'ymax': 119,
#     'ymin': 107}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im992.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 142,
#     'xmin': 123,
#     'ymax': 186,
#     'ymin': 173},
#    {'name': 'garbage', 'xmax': 1113, 'xmin': 1098, 'ymax': 22, 'ymin': 9}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im993.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 124,
#     'xmin': 104,
#     'ymax': 261,
#     'ymin': 242},
#    {'name': 'garbage', 'xmax': 1128, 'xmin': 1107, 'ymax': 83, 'ymin': 69}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im994.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 108,
#     'xmin': 88,
#     'ymax': 335,
#     'ymin': 321},
#    {'name': 'garbage', 'xmax': 1137, 'xmin': 1116, 'ymax': 158, 'ymin': 138}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im995.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 93,
#     'xmin': 68,
#     'ymax': 425,
#     'ymin': 409},
#    {'name': 'garbage', 'xmax': 1152, 'xmin': 1124, 'ymax': 226, 'ymin': 209}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im996.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1158,
#     'xmin': 1133,
#     'ymax': 304,
#     'ymin': 289},
#    {'name': 'garbage', 'xmax': 73, 'xmin': 52, 'ymax': 522, 'ymin': 501},
#    {'name': 'garbage', 'xmax': 586, 'xmin': 558, 'ymax': 70, 'ymin': 48}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im997.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 62,
#     'xmin': 35,
#     'ymax': 630,
#     'ymin': 612},
#    {'name': 'garbage', 'xmax': 582, 'xmin': 563, 'ymax': 131, 'ymin': 106},
#    {'name': 'garbage', 'xmax': 1167, 'xmin': 1140, 'ymax': 385, 'ymin': 367}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im998.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 1174,
#     'xmin': 1147,
#     'ymax': 472,
#     'ymin': 454},
#    {'name': 'garbage', 'xmax': 580, 'xmin': 558, 'ymax': 203, 'ymin': 177}],
#   'width': 1280},
#  {'filename': 'H:\\LUMS\\datasets\\comsats\\garb_xml\\im999.jpg',
#   'height': 720,
#   'object': [{'name': 'garbage',
#     'xmax': 578,
#     'xmin': 558,
#     'ymax': 279,
#     'ymin': 252},
#    {'name': 'garbage', 'xmax': 1178, 'xmin': 1151, 'ymax': 568, 'ymin': 547}],
#   'width': 1280}]

# %%
f = open ('labels.txt', 'w+')
for img_number in range(0,len(train_imgs)):
    image = train_imgs[img_number]
    im_name = image['filename'].split('/')[-1]
    objects = image['object']
    # print (im_name)
    line = im_name
    for objs in objects:
        xmin = objs['xmin']
        ymin = objs['ymin']
        xmax = objs['xmax']
        ymax = objs['ymax']
        c_id = label_ids[objs['name']]
#         print (xmin, ymin, xmax, ymax, c_id)
        line += ' '+str(xmin)+',' +str(ymin)+',' +str(xmax)+','+str(ymax)+','+ str(c_id)

#     print (line)
    f.write (line + '\n')
f.close()
# Out:
# 1617 723 1699 813 0
# 1153 646 1181 667 0
# 551 326 574 357 0
# 545 422 565 450 0
# 532 520 557 548 0
# 515 631 548 659 0
# 858 1 879 21 0
# 855 55 876 79 0
# 850 119 877 141 0
# 848 186 872 209 0
# 158 45 190 66 0
# 850 261 873 287 0
# 140 104 172 127 0
# 121 170 154 189 0
# 846 344 873 375 0
# 848 431 873 464 0
# 103 239 136 264 0
# 82 312 114 344 0
# 844 524 868 564 0
# 59 396 91 431 0
# 838 635 869 674 0
# 170 26 197 45 0
# 152 88 172 114 0
# 33 489 66 525 0
# 9 589 44 625 0
# 128 163 152 187 0
# 103 241 133 266 0
# 79 327 106 354 0
# 49 421 80 451 0
# 18 522 55 555 0
# 342 1 363 20 0
# 325 72 344 90 0
# 307 141 326 159 0
# 288 221 310 241 0
# 269 306 289 330 0
# 248 405 268 431 0
# 1140 238 1160 279 0
# 223 514 244 536 0
# 1144 322 1168 361 0
# 196 636 218 659 0
# 1154 403 1171 449 0
# 1162 494 1182 547 0
# 1167 596 1190 651 0
# 407 27 426 46 0
# 388 97 405 116 0
# 361 173 377 191 0
# 334 258 353 277 0
# 304 348 326 371 0
# 272 456 292 477 0
# 242 571 261 594 0
# 178 36 202 64 0
# 943 64 986 91 0
# 154 102 178 128 0
# 939 133 986 156 0
# 938 201 983 226 0
# 127 176 151 205 0
# 100 262 128 284 0
# 935 280 984 302 0
# 927 365 982 390 0
